# %% [markdown]
# <a href="https://colab.research.google.com/github/shilphypg/MAHE_MSc.DS/blob/master/Python_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/cereal.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9d4c53de077c> in <cell line: 1>()
# ----> 1 df=pd.read_csv('/content/cereal.csv')
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946     kwds.update(kwds_defaults)
# ...

# %%
df1=pd.read_csv('/content/SSLC_Scores.csv')
df1
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66  77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35  25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53  66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62  68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42  64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47  57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59  61   38   46
# 7    8        Dharani R.B       f  16.0    checkers   78   56  51   53   52
# 8    9          Divya T.D       f  17.0    checkers   80   51  70   33   54
# 9   10         Janaki G.J       f   NaN    checkers   94   55  64   41   54
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62  71   50   52
# ...

# %%
#understand the dataframe, shape gives size of the dataset
df1.shape
# Out:
# (37, 14)

# %%
df1.columns # to list the available columns
# Out:
# Index(['Sl', 'Student', 'Gender ', 'Age', 'Hobbies ', 'Kan', 'Eng', 'Hin',
#        'Math', 'Sci', 'S.S.', 'Total', 'Perc', 'Result '],
#       dtype='object')

# %%
len(df1)#to show row
# Out:
# 37

# %%
df1.describe()#understand the dataframe, any outliers,any missing values
# Out:
#               Sl        Age        Kan        Eng        Sci       S.S.  \
# count  37.000000  31.000000  37.000000  37.000000  37.000000  37.000000
# mean   16.918919  16.290323  77.027027  50.432432  50.135135  53.621622
# std     8.772996   1.101319  11.424843  11.586727   9.801253  13.754497
# min     1.000000  12.000000  49.000000  30.000000  25.000000  23.000000
# 25%    10.000000  16.000000  72.000000  42.000000  44.000000  46.000000
# 50%    18.000000  16.000000  78.000000  53.000000  51.000000  54.000000
# 75%    24.000000  17.000000  85.000000  59.000000  54.000000  59.000000
# max    31.000000  18.000000  94.000000  71.000000  71.000000  78.000000
#
#             Total       Perc
# count   37.000000  37.000000
# mean   322.378378  64.556757
# std     63.669438  12.530508
# min    192.000000  38.000000
# 25%    286.000000  57.000000
# 50%    326.000000  65.000000
# 75%    361.000000  72.000000
# max    441.000000  88.000000

# %%
df1[["Student"]].describe()
# Out:
#             Student
# count            37
# unique           31
# top     Sushmitha P
# freq              2

# %%
df1.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Columns: 14 entries, Sl to Result
# dtypes: float64(2), int64(6), object(6)
# memory usage: 4.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sl        37 non-null     int64
#  1   Student   37 non-null     object
#  2   Gender    37 non-null     object
#  3   Age       31 non-null     float64
#  4   Hobbies   37 non-null     object
#  5   Kan       37 non-null     int64
#  6   Eng       37 non-null     int64
#  7   Hin       37 non-null     object
#  8   Math      37 non-null     object
#  9   Sci       37 non-null     int64
#  10  S.S.      37 non-null     int64
#  11  Total     37 non-null     int64
#  12  Perc      37 non-null     float64
#  13  Result    37 non-null     object
# dtypes: float64(2), int64(6), object(6)
# memory usage: 4.2+ KB

# %%
df1.dtypes
# Out:
# Sl            int64
# Student      object
# Gender       object
# Age         float64
# Hobbies      object
# Kan           int64
# Eng           int64
# Hin          object
# Math         object
# Sci           int64
# S.S.          int64
# Total         int64
# Perc        float64
# Result       object
# dtype: object

# %%
df1.tail()
# Out:
#     Sl        Student Gender    Age    Hobbies   Kan  Eng Hin Math  Sci  S.S.  \
# 32  24  Sofiya Khanam       f  17.0    checkers   67   55  66   38   54    46
# 33  25   Srikanth K.B       f  16.0  volleyball   78   35  Ab   Ab   49    59
# 34  26    Sushmitha P       f  16.0  volleyball   77   42  40   43   51    50
# 35  21  Shanmukha G.S       m  18.0       chess   72   34  37   17   38    23
# 36  22   Shravani C.N       f  16.0       chess   82   54  52   30   52    57
#
#     Total  Perc Result
# 32    326  65.0    pass
# 33    221  44.0    fail
# 34    303  61.0    pass
# 35    221  46.0    pass
# 36    327  65.0    pass

# %%
df1.sample() #to check random values
# Out:
#    Sl      Student Gender    Age Hobbies   Kan  Eng Hin Math  Sci  S.S.  \
# 0   1  Adhil Pasha       m  17.0  cricket   81   66  77   52   45    59
#
#    Total  Perc Result
# 0    380  76.0    pass

# %%
df1.sample(10)
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng Hin Math  Sci  \
# 8    9          Divya T.D       f  17.0    checkers   80   51  70   33   54
# 12  13    Misbha Sulthana       f  12.0       chess   66   53  73   34   40
# 11  12        Keerthi M.N       m   NaN       chess   74   30  37   30   40
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62  68   46   64
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62  71   50   52
# 31  12        Keerthi M.N       m   NaN       chess   74   30  37   30   40
# 9   10         Janaki G.J       f   NaN    checkers   94   55  64   41   54
# 25  26        Sushmitha P       f  16.0  volleyball   77   42  40   43   51
# 28  29        Upendra C.V       m  17.0     cricket   70   40  35   18   36
# 35  21      Shanmukha G.S       m  18.0       chess   72   34  37   17   38
#
#     S.S.  Total  Perc Result
# 8     33    321  64.0    pass
# 12    41    307  61.0    pass
# 11    45    256  51.0    pass
# ...

# %%
df1.columns
# Out:
# Index(['Sl', 'Student', 'Gender ', 'Age', 'Hobbies ', 'Kan', 'Eng', 'Hin',
#        'Math', 'Sci', 'S.S.', 'Total', 'Perc', 'Result '],
#       dtype='object')

# %%
import pandas as pd
df1=pd.read_csv('/content/SSLC_Scores.csv')
df1
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66  77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35  25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53  66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62  68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42  64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47  57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59  61   38   46
# 7    8        Dharani R.B       f  16.0    checkers   78   56  51   53   52
# 8    9          Divya T.D       f  17.0    checkers   80   51  70   33   54
# 9   10         Janaki G.J       f   NaN    checkers   94   55  64   41   54
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62  71   50   52
# ...

# %%
df1['Hin']=df1['Hin'].astype('int')
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6ad1850ff9ba> in <cell line: 1>()
# ----> 1 df1['Hin']=df1['Hin'].astype('int')
#       2 df1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6532         else:
#    6533             # else, only a single dtype is given
# -> 6534             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     412             copy = False
#     413
# --> 414         return self.apply(
#     415             "astype",
#     416             dtype=dtype,
#
# ...

# %%
df1.isna().sum()
# Out:
# Sl          0
# Student     0
# Gender      0
# Age         6
# Hobbies     0
# Kan         0
# Eng         0
# Hin         0
# Math        0
# Sci         0
# S.S.        0
# Total       0
# Perc        0
# Result      0
# dtype: int64

# %%
# Check which rows have non-numeric values
non_numeric_rows = df1[~df1['Hin'].str.isnumeric()]
print(non_numeric_rows)

# Filter out non-numeric values and convert the rest
df1['Hin'] = pd.to_numeric(df1['Hin'], errors='coerce').fillna(0).astype('int')

print(df1)
# Out:
#     Sl       Student Gender    Age    Hobbies   Kan  Eng Hin Math  Sci  S.S.  \
# 24  25  Srikanth K.B       f  16.0  volleyball   78   35  Ab   Ab   49    59
# 33  25  Srikanth K.B       f  16.0  volleyball   78   35  Ab   Ab   49    59
#
#     Total  Perc Result
# 24    221  44.0    fail
# 33    221  44.0    fail
#     Sl            Student Gender    Age    Hobbies   Kan  Eng  Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66   77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35   25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53   66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62   68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42   64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47   57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59   61   38   46
# ...

# %%
# Replace non-numeric values with a specific value, e.g., 0
df1['Hin'] = pd.to_numeric(df1['Hin'], errors='coerce').fillna(0).astype('int')

print(df1)
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng  Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66   77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35   25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53   66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62   68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42   64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47   57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59   61   38   46
# 7    8        Dharani R.B       f  16.0    checkers   78   56   51   53   52
# 8    9          Divya T.D       f  17.0    checkers   80   51   70   33   54
# 9   10         Janaki G.J       f   NaN    checkers   94   55   64   41   54
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62   71   50   52
# ...

# %%
df1['Hin']=df1['Hin'].astype('int')
df1
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng  Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66   77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35   25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53   66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62   68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42   64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47   57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59   61   38   46
# 7    8        Dharani R.B       f  16.0    checkers   78   56   51   53   52
# 8    9          Divya T.D       f  17.0    checkers   80   51   70   33   54
# 9   10         Janaki G.J       f   NaN    checkers   94   55   64   41   54
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62   71   50   52
# ...

# %%
df['publishTime']=pd.to_datetime(df['publishTime])

# %%
df1['likecount']=pd.to_numeric(df1['likecount'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'likecount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-c56cdf5e12be> in <cell line: 1>()
# ----> 1 df1['likecount']=pd.to_numeric(df1['likecount'])
#
# ...

# %%
#loc and iloc
df1.iloc[1,3]
# Out:
# 16.0

# %%
df1.iloc[:5]
# Out:
#    Sl            Student Gender    Age  Hobbies   Kan  Eng  Hin Math  Sci  \
# 0   1        Adhil Pasha       m  17.0   cricket   81   66   77   52   45
# 1   2         Anjali P.S       f  16.0     chess   49   35   25   25   25
# 2   3           Asfiya Z       f  17.0   cricket   60   53   66   47   48
# 3   4  Bharath Kumar M.V       m   NaN  checkers   85   62   68   46   64
# 4   5  Bhargav Reddy Y.S       m   NaN   hockey    90   42   64   40   58
#
#    S.S.  Total  Perc Result
# 0    59    380  76.0    pass
# 1    33    192  38.0    fail
# 2    66    340  68.0    pass
# 3    78    403  81.0    pass
# 4    72    366  73.0    pass

# %%
df1.iloc[[5]]
# Out:
#    Sl      Student Gender    Age Hobbies   Kan  Eng  Hin Math  Sci  S.S.  \
# 5   6  Bhavani P.V       f  15.0    chess   84   47   57   34   45    53
#
#    Total  Perc Result
# 5    320  64.0    pass

# %%
df1.iloc[4:10]
# Out:
#    Sl            Student Gender    Age  Hobbies   Kan  Eng  Hin Math  Sci  \
# 4   5  Bhargav Reddy Y.S       m   NaN   hockey    90   42   64   40   58
# 5   6        Bhavani P.V       f  15.0     chess   84   47   57   34   45
# 6   7  Chandra Kanth V.N       m  16.0     chess   77   59   61   38   46
# 7   8        Dharani R.B       f  16.0  checkers   78   56   51   53   52
# 8   9          Divya T.D       f  17.0  checkers   80   51   70   33   54
# 9  10         Janaki G.J       f   NaN  checkers   94   55   64   41   54
#
#    S.S.  Total  Perc Result
# 4    72    366  73.0    pass
# 5    53    320  64.0    pass
# 6    59    340  68.0    pass
# 7    57    347  69.0    pass
# 8    33    321  64.0    pass
# 9    48    356  71.0    pass

# %%
df1.loc[df1['Student']=='Bhavani P.V']
# Out:
#    Sl      Student Gender    Age Hobbies   Kan  Eng  Hin Math  Sci  S.S.  \
# 5   6  Bhavani P.V       f  15.0    chess   84   47   57   34   45    53
#
#    Total  Perc Result
# 5    320  64.0    pass

# %%
df1.loc[df1['Student']=='Bhavani P.V']
# Out:
#    Sl      Student Gender    Age Hobbies   Kan  Eng  Hin Math  Sci  S.S.  \
# 5   6  Bhavani P.V       f  15.0    chess   84   47   57   34   45    53
#
#    Total  Perc Result
# 5    320  64.0    pass

# %%
df1.columns
# Out:
# Index(['Sl', 'Student', 'Gender ', 'Age', 'Hobbies ', 'Kan', 'Eng', 'Hin',
#        'Math', 'Sci', 'S.S.', 'Total', 'Perc', 'Result '],
#       dtype='object')

# %%
df1.loc[df1['Hobbies ']=='chess']
# Out:
#     Sl            Student Gender    Age Hobbies   Kan  Eng  Hin Math  Sci  \
# 1    2         Anjali P.S       f  16.0    chess   49   35   25   25   25
# 5    6        Bhavani P.V       f  15.0    chess   84   47   57   34   45
# 6    7  Chandra Kanth V.N       m  16.0    chess   77   59   61   38   46
# 11  12        Keerthi M.N       m   NaN    chess   74   30   37   30   40
# 12  13    Misbha Sulthana       f  12.0    chess   66   53   73   34   40
# 20  21      Shanmukha G.S       m  18.0    chess   72   34   37   17   38
# 21  22       Shravani C.N       f  16.0    chess   82   54   52   30   52
# 22  23         Sindhu B.C       f  16.0    chess   91   65   78   47   67
# 31  12        Keerthi M.N       m   NaN    chess   74   30   37   30   40
# 35  21      Shanmukha G.S       m  18.0    chess   72   34   37   17   38
# 36  22       Shravani C.N       f  16.0    chess   82   54   52   30   52
#
#     S.S.  Total  Perc Result
# 1     33    192  38.0    fail
# ...

# %%
df1[(df1['Student']=='Bhavani P.V')&(df1['Hobbies ']=='chess')]
# Out:
#    Sl      Student Gender    Age Hobbies   Kan  Eng  Hin Math  Sci  S.S.  \
# 5   6  Bhavani P.V       f  15.0    chess   84   47   57   34   45    53
#
#    Total  Perc Result
# 5    320  64.0    pass

# %%
df1['Total']=min

# %%
df1
# Out:
#     Sl            Student Gender    Age    Hobbies   Kan  Eng  Hin Math  Sci  \
# 0    1        Adhil Pasha       m  17.0     cricket   81   66   77   52   45
# 1    2         Anjali P.S       f  16.0       chess   49   35   25   25   25
# 2    3           Asfiya Z       f  17.0     cricket   60   53   66   47   48
# 3    4  Bharath Kumar M.V       m   NaN    checkers   85   62   68   46   64
# 4    5  Bhargav Reddy Y.S       m   NaN     hockey    90   42   64   40   58
# 5    6        Bhavani P.V       f  15.0       chess   84   47   57   34   45
# 6    7  Chandra Kanth V.N       m  16.0       chess   77   59   61   38   46
# 7    8        Dharani R.B       f  16.0    checkers   78   56   51   53   52
# 8    9          Divya T.D       f  17.0    checkers   80   51   70   33   54
# 9   10         Janaki G.J       f   NaN    checkers   94   55   64   41   54
# 10  11      Ghansi Rani S       f  17.0    checkers   92   62   71   50   52
# ...

# %%
df1=df1[df1['Student'].str.startswith('B')]
df1
# Out:
#    Sl            Student Gender    Age  Hobbies   Kan  Eng  Hin Math  Sci  \
# 3   4  Bharath Kumar M.V       m   NaN  checkers   85   62   68   46   64
# 4   5  Bhargav Reddy Y.S       m   NaN   hockey    90   42   64   40   58
# 5   6        Bhavani P.V       f  15.0     chess   84   47   57   34   45
#
#    S.S.                    Total  Perc Result
# 3    78  <built-in function min>  81.0    pass
# 4    72  <built-in function min>  73.0    pass
# 5    53  <built-in function min>  64.0    pass

# %%
df1.dropna(axis=0,how='all')
# Out:
#    Sl            Student Gender    Age  Hobbies   Kan  Eng  Hin Math  Sci  \
# 3   4  Bharath Kumar M.V       m   NaN  checkers   85   62   68   46   64
# 4   5  Bhargav Reddy Y.S       m   NaN   hockey    90   42   64   40   58
# 5   6        Bhavani P.V       f  15.0     chess   84   47   57   34   45
#
#    S.S.                    Total  Perc Result
# 3    78  <built-in function min>  81.0    pass
# 4    72  <built-in function min>  73.0    pass
# 5    53  <built-in function min>  64.0    pass

# %%
df1.dropna(axis=1,how='any')
# Out:
#    Sl            Student Gender   Hobbies   Kan  Eng  Hin Math  Sci  S.S.  \
# 3   4  Bharath Kumar M.V       m  checkers   85   62   68   46   64    78
# 4   5  Bhargav Reddy Y.S       m   hockey    90   42   64   40   58    72
# 5   6        Bhavani P.V       f     chess   84   47   57   34   45    53
#
#                      Total  Perc Result
# 3  <built-in function min>  81.0    pass
# 4  <built-in function min>  73.0    pass
# 5  <built-in function min>  64.0    pass
